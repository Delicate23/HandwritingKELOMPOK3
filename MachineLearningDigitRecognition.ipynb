# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from google.colab import drive
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D
# from tensorflow.keras.layers import MaxPooling2D
# from tensorflow.keras.layers import Dense
# from tensorflow.keras.layers import Flatten
drive.mount('/content/gdrive', force_remount=True)
import struct
import gzip
# Out:
# Mounted at /content/gdrive

# %%
# READ DATA MNIST
def read_idx(filename):
    with gzip.open(filename) as f:
        zero, data_type, dims = struct.unpack('>HBB', f.read(4))
        shape = tuple(struct.unpack('>I', f.read(4))[0] for d in range(dims))
        return np.fromstring(f.read(), dtype=np.uint8).reshape(shape)

X_train = read_idx('/content/gdrive/My Drive/Colab Notebooks/train-images-idx3-ubyte.gz')
y_train = read_idx('/content/gdrive/My Drive/Colab Notebooks/train-labels-idx1-ubyte.gz')
X_test = read_idx('/content/gdrive/My Drive/Colab Notebooks/t10k-images-idx3-ubyte.gz')
y_test = read_idx('/content/gdrive/My Drive/Colab Notebooks/t10k-labels-idx1-ubyte.gz')
# Normalizing the data (making length = 1)
X_train = tf.keras.utils.normalize(X_train, axis=1)
idx = np.argsort(y_train)
X_train = X_train[idx]
y_train = y_train[idx]
x_train_zeros = X_train[y_train == 0]
x_train_zeros = X_train
x_train_zeros = x_train_zeros[:5000]
x_train_ones = X_train[y_train == 1]
x_train_ones = x_train_ones[:5000]
x_train_two = X_train[y_train == 2]
x_train_two = x_train_two[:5000]
x_train_three = X_train[y_train == 3]
x_train_three = x_train_three[:2000]
x_train_four = X_train[y_train == 4]
x_train_four = x_train_four[:5000]
x_train_five = X_train[y_train == 5]
x_train_five = x_train_five[:5000]
x_train_six = X_train[y_train == 6]
x_train_six = x_train_six[:5000]
x_train_seven = X_train[y_train == 7]
x_train_seven = x_train_seven[:5000]
x_train_eight = X_train[y_train == 8]
x_train_eight = x_train_eight[:5000]
x_train_nine = X_train[y_train == 9]
x_train_nine = x_train_nine[:5000]
y_train_zeros = y_train[y_train == 0]
y_train_zeros = y_train_zeros[:5000]
y_train_ones = y_train[y_train == 1]
y_train_ones = y_train_ones[:5000]
y_train_two = y_train[y_train == 2]
y_train_two = y_train_two[:5000]
y_train_three = y_train[y_train == 3]
y_train_three = y_train_three[:2000]
y_train_four = y_train[y_train == 4]
y_train_four = y_train_four[:5000]
y_train_five = y_train[y_train == 5]
y_train_five = y_train_five[:5000]
y_train_six = y_train[y_train == 6]
y_train_six = y_train_six[:5000]
y_train_seven = y_train[y_train == 7]
y_train_seven = y_train_seven[:5000]
y_train_eight = y_train[y_train == 8]
y_train_eight = y_train_eight[:5000]
y_train_nine = y_train[y_train == 9]
y_train_nine = y_train_nine[:5000]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead

# %%
# READ DATA
# DATASET KELOMPOK SENDIRI
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 3/digit 0/img({}).png'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 3/digit 0/img({}).png'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(np.array([img_training]))
      x_train_zeros = np.concatenate((x_train_zeros, img_training))
      y_train_zeros = np.append(y_train_zeros, 0)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 0")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 3/digit 1/img({}).png'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 3/digit 1/img({}).png'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(np.array([img_training]))
      x_train_ones = np.concatenate((x_train_ones, img_training))
      y_train_ones = np.append(y_train_ones, 1)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 1")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 3/digit 2/img({}).png'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 3/digit 2/img({}).png'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(np.array([img_training]))
      x_train_two = np.concatenate((x_train_two, img_training))
      y_train_two = np.append(y_train_two, 2)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 2")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 3/digit 3/img({}).png'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 3/digit 3/img({}).png'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(np.array([img_training]))
      x_train_three = np.concatenate((x_train_three, img_training))
      y_train_three = np.append(y_train_three, 3)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 3")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 3/digit 4/img({}).png'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 3/digit 4/img({}).png'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(np.array([img_training]))
      x_train_four = np.concatenate((x_train_four, img_training))
      y_train_four = np.append(y_train_four, 4)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 4")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 3/digit 5/img({}).png'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 3/digit 5/img({}).png'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(np.array([img_training]))
      x_train_five = np.concatenate((x_train_five, img_training))
      y_train_five = np.append(y_train_five, 5)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 5")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 3/digit 6/img({}).png'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 3/digit 6/img({}).png'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(np.array([img_training]))
      x_train_six = np.concatenate((x_train_six, img_training))
      y_train_six = np.append(y_train_six, 6)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 6")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 3/digit 7/img({}).png'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 3/digit 7/img({}).png'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(np.array([img_training]))
      x_train_seven = np.concatenate((x_train_seven, img_training))
      y_train_seven = np.append(y_train_seven, 7)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 7")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 3/digit 8/img({}).png'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 3/digit 8/img({}).png'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(np.array([img_training]))
      x_train_eight = np.concatenate((x_train_eight, img_training))
      y_train_eight = np.append(y_train_eight, 8)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 8")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 3/digit 9/img({}).png'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 3/digit 9/img({}).png'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(np.array([img_training]))
      x_train_nine = np.concatenate((x_train_nine, img_training))
      y_train_nine = np.append(y_train_nine, 9)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 9")
# Out:
# done 0
# done 1
# done 2
# done 3
# done 4
# done 5
# done 6
# done 7
# done 8
# done 9

# %%
# DATASET KELOMPOK LAIN - KEL 4
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 4/Angka 0/0.{}.png'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 4/Angka 0/0.{}.png'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(np.array([img_training]))
      x_train_zeros = np.concatenate((x_train_zeros, img_training))
      y_train_zeros = np.append(y_train_zeros, 0)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 0")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 4/Angka 1/1.{}.png'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 4/Angka 1/1.{}.png'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(np.array([img_training]))
      x_train_ones = np.concatenate((x_train_ones, img_training))
      y_train_ones = np.append(y_train_ones, 1)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 1")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 4/Angka 2/2.{}.png'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 4/Angka 2/2.{}.png'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(np.array([img_training]))
      x_train_two = np.concatenate((x_train_two, img_training))
      y_train_two = np.append(y_train_two, 2)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 2")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 4/Angka 3/3.{}.png'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 4/Angka 3/3.{}.png'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(np.array([img_training]))
      x_train_three = np.concatenate((x_train_three, img_training))
      y_train_three = np.append(y_train_three, 3)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 3")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 4/Angka 4/4.{}.png'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 4/Angka 4/4.{}.png'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(np.array([img_training]))
      x_train_four = np.concatenate((x_train_four, img_training))
      y_train_four = np.append(y_train_four, 4)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 4")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 4/Angka 5/5.{}.png'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 4/Angka 5/5.{}.png'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(np.array([img_training]))
      x_train_five = np.concatenate((x_train_five, img_training))
      y_train_five = np.append(y_train_five, 5)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 5")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 4/Angka 6/6.{}.png'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 4/Angka 6/6.{}.png'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(np.array([img_training]))
      x_train_six = np.concatenate((x_train_six, img_training))
      y_train_six = np.append(y_train_six, 6)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 6")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 4/Angka 7/7.{}.png'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 4/Angka 7/7.{}.png'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(np.array([img_training]))
      x_train_seven = np.concatenate((x_train_seven, img_training))
      y_train_seven = np.append(y_train_seven, 7)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 7")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 4/Angka 8/8.{}.png'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 4/Angka 8/8.{}.png'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(np.array([img_training]))
      x_train_eight = np.concatenate((x_train_eight, img_training))
      y_train_eight = np.append(y_train_eight, 8)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 8")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 4/Angka 9/9.{}.png'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 4/Angka 9/9.{}.png'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(np.array([img_training]))
      x_train_nine = np.concatenate((x_train_nine, img_training))
      y_train_nine = np.append(y_train_nine, 9)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 9")
# Out:
# done 0
# done 1
# done 2
# done 3
# done 4
# done 5
# done 6
# done 7
# done 8
# done 9

# %%
# DATASET KELOMPOK LAIN - KEL 10
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 10/0/img ({}).jpg'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 10/0/img ({}).jpg'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(img_training)
      img_training = np.invert(np.array([img_training]))
      x_train_zeros = np.concatenate((x_train_zeros, img_training))
      y_train_zeros = np.append(y_train_zeros, 0)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 0")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 10/1/img ({}).jpg'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 10/1/img ({}).jpg'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(img_training)
      img_training = np.invert(np.array([img_training]))
      x_train_ones = np.concatenate((x_train_ones, img_training))
      y_train_ones = np.append(y_train_ones, 1)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 1")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 10/2/img ({}).jpg'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 10/2/img ({}).jpg'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(img_training)
      img_training = np.invert(np.array([img_training]))
      x_train_two = np.concatenate((x_train_two, img_training))
      y_train_two = np.append(y_train_two, 2)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 2")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 10/3/img ({}).jpg'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 10/3/img ({}).jpg'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(img_training)
      img_training = np.invert(np.array([img_training]))
      x_train_three = np.concatenate((x_train_three, img_training))
      y_train_three = np.append(y_train_three, 3)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 3")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 10/4/img ({}).jpg'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 10/4/img ({}).jpg'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(img_training)
      img_training = np.invert(np.array([img_training]))
      x_train_four = np.concatenate((x_train_four, img_training))
      y_train_four = np.append(y_train_four, 4)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 4")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 10/5/img ({}).jpg'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 10/5/img ({}).jpg'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(img_training)
      img_training = np.invert(np.array([img_training]))
      x_train_five = np.concatenate((x_train_five, img_training))
      y_train_five = np.append(y_train_five, 5)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 5")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 10/6/img ({}).jpg'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 10/6/img ({}).jpg'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(img_training)
      img_training = np.invert(np.array([img_training]))
      x_train_six = np.concatenate((x_train_six, img_training))
      y_train_six = np.append(y_train_six, 6)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 6")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 10/7/img ({}).jpg'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 10/7/img ({}).jpg'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(img_training)
      img_training = np.invert(np.array([img_training]))
      x_train_seven = np.concatenate((x_train_seven, img_training))
      y_train_seven = np.append(y_train_seven, 7)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 7")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 10/8/img ({}).jpg'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 10/8/img ({}).jpg'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(img_training)
      img_training = np.invert(np.array([img_training]))
      x_train_eight = np.concatenate((x_train_eight, img_training))
      y_train_eight = np.append(y_train_eight, 8)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 8")
image_number_training = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/datasetKel 10/9/img ({}).jpg'.format(image_number_training)):
    try:
      img_training = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/datasetKel 10/9/img ({}).jpg'.format(image_number_training))[:,:,0]
      img_training = cv2.resize(img_training, (28, 28))
      img_training = np.invert(img_training)
      img_training = np.invert(np.array([img_training]))
      x_train_nine = np.concatenate((x_train_nine, img_training))
      y_train_nine = np.append(y_train_nine, 9)
      image_number_training += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number_training += 1
print("done 9")
# Out:
# done 0
# done 1
# done 2
# done 3
# done 4
# done 5
# done 6
# done 7
# done 8
# done 9

# %%
X_train = np.concatenate((x_train_zeros, x_train_ones, x_train_two, x_train_three, x_train_four, x_train_five, x_train_six, x_train_seven, x_train_eight, x_train_nine))
y_train = np.concatenate((y_train_zeros, y_train_ones, y_train_two, y_train_three, y_train_four, y_train_five, y_train_six, y_train_seven, y_train_eight, y_train_nine))
X_test = tf.keras.utils.normalize(X_test, axis=1)

# show train dataset image
# print(y_train_zeros[100000])
# image = np.asarray(x_train_zeros[5000]).squeeze()
# plt.imshow(image)
# plt.show()

# Create a neural network model
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2D(32, (5, 5), input_shape=(28, 28, 1), activation='relu'))
model.add(tf.keras.layers.MaxPooling2D())
model.add(tf.keras.layers.Conv2D(32, (5, 5), input_shape=(28, 28, 1), activation='relu'))
model.add(tf.keras.layers.MaxPooling2D())
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(units=128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(units=128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(units=10, activation=tf.nn.softmax))

# Compiling and optimizing model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Training the model
model.fit(X_train, y_train, epochs=3)

# Evaluating the model
val_loss, val_acc = model.evaluate(X_test, y_test)
print(val_loss)
print(val_acc)

# Testing
image_number = 1
while os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/digits/digit({}).png'.format(image_number)):
    try:
        img = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/digits/digit({}).png'.format(image_number))[:,:,0]
        if image_number > 100 and image_number <= 150:
          img = np.invert(img)
        img = np.invert(np.array([img]))
        prediction = model.predict(img)
        print("The number is probably a {}".format(np.argmax(prediction)))
        plt.imshow(img[0], cmap=plt.cm.binary)
        plt.show()
        image_number += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number += 1
# Out:
# Epoch 1/3
# 1500/1500 [==============================] - 44s 29ms/step - loss: 0.5268 - accuracy: 0.8524
# Epoch 2/3
# 1500/1500 [==============================] - 43s 29ms/step - loss: 0.1134 - accuracy: 0.9669
# Epoch 3/3
# ...
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0530 - accuracy: 0.9830
# 0.05303627997636795
# 0.9829999804496765
# The number is probably a 7
# The number is probably a 3
# The number is probably a 7
# The number is probably a 7
# The number is probably a 7
# The number is probably a 7
# The number is probably a 7
# The number is probably a 9
# The number is probably a 9
# The number is probably a 8
# The number is probably a 8
# The number is probably a 8
# The number is probably a 1
# The number is probably a 1
# The number is probably a 3
# The number is probably a 2
# The number is probably a 7
# The number is probably a 7
# The number is probably a 7
# The number is probably a 7
# The number is probably a 7
# The number is probably a 7
# ...
